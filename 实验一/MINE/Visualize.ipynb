# %%
import pandas as pd
import seaborn as sns; sns.set_theme()
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 300
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
nodes = pd.read_csv("nodes.csv")
nodes.head()
# Out:
#             Label attribute  degree  modularity_class  Eccentricity
# 0  uncoordination   symptom       2                 0             6  \
# 1           fever   symptom      38                 3             4
# 2  pleuritic pain   symptom      13                 3             6
# 3         snuffle   symptom       5                 3             6
# 4     throat sore   symptom       6                 3             6
#
#    closnesscentrality  harmonicclosnesscentrality  betweenesscentrality
# 0            0.263889                    0.279673             30.917920  \
# 1            0.350509                    0.410920           9871.893058
# 2            0.300436                    0.333091            669.106219
# 3            0.281122                    0.302450            124.238187
# 4            0.286085                    0.308469            208.454569
#
#    pageranks  eigencentrality
# 0   0.000692         0.035145
# 1   0.007680         0.807265
# 2   0.002635         0.327562
# 3   0.001275         0.114408
# 4   0.001438         0.144130

# %%
counts = nodes['modularity_class'].value_counts()
plt.pie(counts, labels = counts.index, explode=[0.02 for _ in range(len(counts))], autopct='%1.1f%%')
plt.title("不同社团比重")
plt.show()

# %%
sns.displot(nodes, x="closnesscentrality")
plt.title("接近中心性分布")
plt.xlabel("Clossness Centrality")
plt.show()

# %%
sns.displot(nodes, x="betweenesscentrality")
plt.title("介数中心性分布")
plt.xlabel("Betweeness Centrality")
plt.show()

# %%
sns.displot(nodes, x="pageranks")
plt.title("PageRank分布")
plt.xlabel("PageRank")
plt.show()

# %%
sns.displot(nodes, x="eigencentrality")
plt.title("特征向量中心性分布")
plt.xlabel("Eigenvector Centrality")
plt.show()
